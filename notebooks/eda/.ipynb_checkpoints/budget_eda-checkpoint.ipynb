# %%
import os
os.environ['XDG_CACHE_HOME'] = 'home/msds2022/mpingol/ .cache'

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import itertools
from itertools import chain

import pickle
#import shap
import re
import time
import string

import torch
import tensorflow as tf

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import *
from nltk import word_tokenize

from keybert import KeyBERT
from keyphrase_vectorizers import KeyphraseCountVectorizer
from keyphrase_vectorizers import KeyphraseTfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import pairwise_distances
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import cosine_similarity

from datasets import load_dataset, load_metric
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer, PegasusTokenizer

from sentence_transformers import SentenceTransformer, util
import umap.umap_ as umap

from catboost import CatBoostClassifier, Pool
import seaborn as sns
#from ctfidf import CTFIDFVectorizer
from scipy import stats
import json

# %%
df = pd.ExcelFile('research_profile_updated.xlsx').parse('research_profile')

# %%
df

# %%
df.columns

# %%
df['Allocated Budget (PH Pesos) 1,000,000.00']

# %%
rp_df = df[['Research Title', 'Keywords', 'Abstract', 'SDG', 'NEDA Priority Area', 'Allocated Budget (PH Pesos) 1,000,000.00']].copy()
rp_df.columns = ['title', 'keywords', 'abstract', 'sdg', 'neda', 'budget']

# %%
def remove_punctuations(data):
    punct = set(string.punctuation)
    punct.add("’")
    data = ("").join([ch for ch in data if ch not in punct])
    return data

def remove_stopwords(data):
    stop_words = stopwords.words('english')
    data = (" ").join([word for word in data.split() if word not in stop_words])
    return data

def remove_univ_words(data):
    univ_words = df[['University (Full Name)', 'University (Abbreviation)', 'Campus', 'City/Municipality', 'Province', 'Region']]
    univ_words = univ_words.values.tolist()
    univ_words = set(list(chain.from_iterable(univ_words)))
    univ_words.add("del")
    univ_words.add("norte")
    univ_words.add("college")
    univ_words.add("university")    
    univ_words.add("state") 
    univ_words.add("del norte")
    univ_words.add("del norte state")
    univ_words.add("norte state")
    univ_words.add("state college")
    univ_words.add("state university")
    univ_words.add("study conducted")
    data = (" ").join([word for word in data.split() if word not in univ_words])
    return data

def lemma_corpus(data):
    lemmatizer = WordNetLemmatizer()
    data = (" ").join([lemmatizer.lemmatize(word) for word in data.split()])
    return data

def replace_delimiter(data):
    data = re.sub(r"; ", " ", data)
    data = re.sub(r", ", " ", data)
    data = re.sub(r";", " ", data)
    data = re.sub(r",", " ", data)
    return data

def plot_loghist(x, bins):
    hist, bins = np.histogram(x, bins=bins)
    logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
    plt.hist(x, bins=logbins)
    plt.xscale('log')
    plt.title('Distribution (Log Scale)')

# %%
# process titles
rp_df['title_processed'] = None
for idx in rp_df.index:
    try:
        data = rp_df['title'].loc[idx]
        data = remove_punctuations(data)
        data = remove_stopwords(data)
        data = remove_univ_words(data)
        data = lemma_corpus(data)
        rp_df['title_processed'].loc[idx] = data
    except:
        continue
        
# process keywords
rp_df['keywords_processed'] = None
for idx in rp_df.index:
    try:
        data = rp_df['keywords'].loc[idx]
        data = replace_delimiter(data)
        data = remove_stopwords(data)
        data = remove_univ_words(data)
        data = lemma_corpus(data)
        rp_df['keywords_processed'].loc[idx] = data
    except:
        continue
        
# process abstract
rp_df['abstract_processed'] = None
for idx in rp_df.index:
    try:
        data = rp_df['abstract'].loc[idx]
        data = remove_punctuations(data)
        data = remove_stopwords(data)
        data = remove_univ_words(data)
        data = lemma_corpus(data)
        rp_df['abstract_processed'].loc[idx] = data
    except:
        continue

# %%
rp_df['keywords_processed'].fillna("", inplace=True)
rp_df['abstract_processed'].fillna("", inplace=True)

# create corpus
rp_df['corpus'] = None
for idx in rp_df.index:
    try:
        rp_df['corpus'].loc[idx] = (rp_df['title'].loc[idx] + 
                                    rp_df['abstract'].loc[idx] + 
                                    rp_df['keywords'].loc[idx])
    except:
        continue
        
# create processed corpus
rp_df['corpus_processed'] = None
for idx in rp_df.index:
    try:
        rp_df['corpus_processed'].loc[idx] = (rp_df['title_processed'].loc[idx] + 
                                              rp_df['abstract_processed'].loc[idx] + 
                                              rp_df['keywords_processed'].loc[idx])
    except:
        continue

# %%
# sdg processessing
sdg_pred = rp_df[rp_df['sdg'].isnull()].index
sdg_idx = rp_df[(rp_df['sdg'].notnull())].index
sdg_df = rp_df[['corpus_processed', 'sdg']].loc[sdg_idx].copy()

print("Before Processing")
display(sdg_df['sdg'].apply(lambda x: type(x)).value_counts())
sdg_df['sdg_type'] = sdg_df['sdg'].apply(lambda x: type(x))

for idx in sdg_df[sdg_df['sdg_type'] == str].index:
    sdg_df['sdg'].loc[idx] = np.random.choice(sdg_df['sdg'].loc[idx].split(';'))
    
sdg_df = sdg_df.drop('sdg_type', axis=1)
sdg_df['sdg'] = sdg_df['sdg'].apply(lambda x: int(x))

print("After Processing")
display(sdg_df['sdg'].apply(lambda x: type(x)).value_counts())

sdg_df['sdg'].value_counts().plot(kind='bar');

# %%
train, test = train_test_split(sdg_idx, test_size=0.33)

train_features = sdg_df['corpus_processed'].loc[train].values
test_features = sdg_df['corpus_processed'].loc[test].values
pred_features = rp_df['corpus_processed'].loc[sdg_pred].values

train_labels = sdg_df['sdg'].loc[train]
test_labels = sdg_df['sdg'].loc[test]

sbert = SentenceTransformer('allenai/specter')
sbert.max_seq_length =  512

train_embeddings = sbert.encode(train_features, convert_to_tensor=True)
test_embeddings = sbert.encode(test_features, convert_to_tensor=True)
pred_embeddings = sbert.encode(pred_features, convert_to_tensor=True)

train_embeddings = train_embeddings.cpu()
test_embeddings = test_embeddings.cpu()
pred_embeddings = pred_embeddings.cpu()

# %%
fin_lr = LogisticRegression(C=0.01, max_iter=100, penalty='l2', solver='saga')
fin_lr = fin_lr.fit(train_embeddings, train_labels)
fin_preds = fin_lr.predict(pred_embeddings)
print(accuracy_score(fin_lr.predict(test_embeddings), test_labels))

# %%
for idx1, idx2 in enumerate(sdg_pred):
    df['SDG'].loc[idx2] = fin_preds[idx1]

# %%
df['SDG'].isnull().sum()

# %%
kw_model = KeyBERT('allenai/specter')
def gen_kp(text):
    corpus = []
    corpus.append(text)
    tfidf_vectorizer = KeyphraseTfidfVectorizer()
    tfidf_vectorizer.fit_transform(corpus).toarray()
    keyphrases = kw_model.extract_keywords(docs=corpus, vectorizer=tfidf_vectorizer)
    keyphrases = (", ").join([phrase[0] for phrase in keyphrases[0]])
    return keyphrases

# %%
# %%capture
# generate keywords
rp_df['keyphrases_corpus_processed'] = None
for idx in rp_df.index:
    try:
        rp_df['keyphrases_corpus_processed'].loc[idx] = gen_kp(rp_df['corpus_processed'].loc[idx])
    
    except:
        continue

# %%
kp_idx = rp_df['keyphrases_corpus_processed'].notnull().index

# %%
for idx in kp_idx:
    df['Keywords'].loc[idx] = rp_df['keyphrases_corpus_processed'].loc[idx]

# %%
df['Keywords'].notnull()

# %%
# create budget df
budget_df = rp_df[['corpus_processed', 'budget']].dropna().copy()

# check type
print("Before Processing")
display(budget_df['budget'].apply(lambda x: type(x)).value_counts())

# convert string to int
budget_df['budget'][657] = (50000+70000)
budget_df['budget'][740] = 75000
budget_df['budget'][844] = 422745

# convert int to float
budget_df['budget'] = budget_df['budget'].apply(lambda x: float(x))

# check type again
print("After Processing")
display(budget_df['budget'].apply(lambda x: type(x)).value_counts())

# %%
df.columns

# %%
for idx in budget_df.index:
    df['Allocated Budget (PH Pesos) 1,000,000.00'].loc[idx] = budget_df['budget'].loc[idx]

# %%
df['Allocated Budget (PH Pesos) 1,000,000.00'].notnull().sum()

# %%
df.columns

# %%
univ = df[['University (Abbreviation)', 'Allocated Budget (PH Pesos) 1,000,000.00']]
univ.columns = ['University', 'Budget']
univ_counts = pd.DataFrame(univ.groupby('University')['University'].agg('count'))
univ_counts = univ_counts.rename({'University':'Research Count'}, axis=1)


univ_budget = pd.DataFrame(univ.groupby('University')['Budget'].agg('sum'))
univ_budget = univ_budget.rename({'Budget':'Total Budget'}, axis=1)

univ_final = univ_counts.join(univ_budget)
univ_final['Ratio'] = univ_final['Total Budget']/univ_final['Research Count']
univ_final['Ratio'] = univ_final['Ratio'].apply(lambda x: round(x))

univ_final['Total Budget'] = univ_final['Total Budget'].apply(lambda x: (x/1000000))

univ_final
# Out:
#             Research Count  Total Budget     Ratio
# University
# ADMU                     1     10.000000  10000000
# ASIST                  269      1.083903      4029
# ASSCAT                  29      1.020000     35172
# ASU                      2      6.173585   3086792
# AU                       1      4.000000   4000000
# ...                    ...           ...       ...
# USTSP                    1      3.600000   3600000
# WMSU                     2     12.270092   6135046
# WPU                      1     10.000000  10000000
# XU                       1     10.000000  10000000
# ZCPC                     1      1.093798   1093798
#
# [67 rows x 3 columns]

# %%
plt.figure(figsize=(10,10), dpi=300);
plt.scatter(x=univ_final['Total Budget'], y=univ_final['Research Count'], color='green')

plt.xlabel('Total Budget');
plt.ylabel('Research Counts');
plt.tick_params(axis='both', which='both', length=0);
plt.gca().spines.right.set_visible(False);
plt.gca().spines.top.set_visible(False);
plt.gca().spines.bottom.set_visible(False);

# %%
def get_research_cost_university_scatter(df='../data/cleaned/research_profile_updated.xlsx'):
    df = pd.read_excel(df)
    univ = df[['University (Abbreviation)', 'Allocated Budget (PH Pesos) 1,000,000.00']]
    univ.columns = ['University', 'Budget']
    univ_counts = pd.DataFrame(univ.groupby('University')['University'].agg('count'))
    univ_counts = univ_counts.rename({'University':'Research Count'}, axis=1)

    univ_budget = pd.DataFrame(univ.groupby('University')['Budget'].agg('sum'))
    univ_budget = univ_budget.rename({'Budget':'Total Budget'}, axis=1)

    univ_final = univ_counts.join(univ_budget)
    univ_final['Ratio'] = univ_final['Total Budget']/univ_final['Research Count']
    univ_final['Ratio'] = univ_final['Ratio'].apply(lambda x: round(x))

    return univ_final.to_json(orient='columns')

# %%
region = df[['Region', 'Allocated Budget (PH Pesos) 1,000,000.00']]
region.columns = ['Region', 'Budget']
region_counts = pd.DataFrame(region.groupby('Region')['Region'].agg('count'))
region_counts = region_counts.rename({'Region':'Research Count'}, axis=1)

region_budget = pd.DataFrame(region.groupby('Region')['Budget'].agg('sum'))
region_budget = region_budget.rename({'Budget':'Total Budget'}, axis=1)

region_final = region_counts.join(region_budget)
region_final['Ratio'] = region_final['Total Budget']/region_final['Research Count']
region_final['Ratio'] = region_final['Ratio'].apply(lambda x: round(x))

region_final['Total Budget'] = region_final['Total Budget'].apply(lambda x: (x/1000000))


region_final
# Out:
#         Research Count  Total Budget    Ratio
# Region
# 1                    4     12.537197  3134299
# 2                   17     20.515000  1206765
# 3                  177     81.864621   462512
# 5                    2     14.000000  7000000
# 6                   11     29.999040  2727186
# 7                    5     14.817873  2963575
# 8                   10     16.886364  1688636
# 9                    4     13.733496  3433374
# 10                   2     13.600000  6800000
# 11                  74     33.148097   447947
# 12                   4     19.689938  4922484
# 13                  31     16.462616   531052
# 4A                   7     21.021278  3003040
# 4B                 263     11.161195    42438
# BARMM                1      4.000000  4000000
# CAR                651     44.591019    68496
# NCR                 16     84.727664  5295479

# %%
df_budget = df['Allocated Budget (PH Pesos) 1,000,000.00'].copy()
df_budget.columns = ['budget']

# %%
notnull_index = df_budget[df_budget.notnull()].index

# %%
zero_index = df_budget[df_budget > 0].index

# %%
df_budget = df_budget.loc[(notnull_index & zero_index)]

# %%
x = df_budget
bins = 20
hist, bins = np.histogram(x, bins=bins);
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins));
plt.figure(figsize=(12,7), dpi=600);
plt.hist(x, bins=logbins, color='green');
plt.xscale('log');
plt.xlabel('Research Counts', fontsize=16);
plt.ylabel('Budget Value', fontsize=16);
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tick_params(axis='both', which='both', length=0);
plt.gca().spines.right.set_visible(False);
plt.gca().spines.top.set_visible(False);
plt.gca().spines.bottom.set_visible(False);

# %%
univ_final

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,6), dpi=600)
sns.scatterplot(x=univ_final['Total Budget'], y=univ_final['Research Count'], ax=ax1, color='green')
sns.scatterplot(x=region_final['Total Budget'], y=region_final['Research Count'],ax=ax2, color='green')
ax1.tick_params(axis='both', which='both', length=0);
ax2.tick_params(axis='both', which='both', length=0);
ax1.set_title('University', fontsize=16)
ax2.set_title('Region', fontsize=16)
#plt.xticks(fontsize=16)
#plt.yticks(fontsize=16)
ax1.set_xlabel('Total Budget', fontsize=16);
ax1.set_ylabel('Research Counts', fontsize=16);
ax2.set_xlabel('Total Budget', fontsize=16);
ax2.set_ylabel('Research Counts', fontsize=16);
#plt.gca().spines.right.set_visible(False);
#plt.gca().spines.top.set_visible(False);
#plt.gca().spines.bottom.set_visible(False);
ax1.tick_params(labelsize=16)  # Adjust to fit
ax2.tick_params(labelsize=16)  # Adjust to fit
sns.set_style("white")
plt.show()

# %%
df
