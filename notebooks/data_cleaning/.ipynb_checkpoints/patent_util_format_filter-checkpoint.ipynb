# %%
import re
import datetime
import pandas as pd

# %% [markdown]
# ## Patents

# %%
df_patents = pd.read_excel('patents.xlsx')

# %%
df_patents
# Out:
#     Team Member Input Date  Research Title  \
# 0         Chris 2022-04-05             NaN
# 1         Chris 2022-04-05             NaN
# 2         Chris 2022-04-05             NaN
# 3         Chris 2022-04-05             NaN
# 4         Chris 2022-04-05             NaN
# ..          ...        ...             ...
# 193      Marvee 2022-04-06             NaN
# 194      Marvee 2022-04-06             NaN
# 195      Marvee 2022-04-06             NaN
# 196      Marvee 2022-04-06             NaN
# 197      Marvee 2022-04-06             NaN
#
#                                           Patent Filed    Patent Type  \
# 0                 Radio Frequency-Based Mobile Charger  Utility Model
# 1    Process Of Producing Molluscide Mixture From E...  Utility Model
# 2    Process Of Producing Tiessa (Pouteria Campechi...  Utility Model
# 3    Process Of Constructing An Educational Mathema...  Utility Model
# 4    Process Of Constructing An Educational Mathema...  Utility Model
# ..                                                 ...            ...
# 193  A Composition Of Rice Hull Char – Based Compos...  Utility Model
# 194                A Method Of Making Multipurpose Bag  Utility Model
# 195                A Method Of Making Sando Market Bag  Utility Model
# 196    A Method Of Making Multifunctional Sleeping Bag  Utility Model
# 197                      A Method Of Making Summer Hat  Utility Model
#
#     Patent Status Date of Registration Registration Number  \
# 0      Registered           2020-04-22       2-2018-000289
# 1      Registered           2020-10-02       2-2018-000326
# 2      Registered           2020-08-07       2-2019-001395
# 3      Registered           2020-02-19       2-2019-001396
# 4      Registered           2020-02-19       2-2019-001397
# ..            ...                  ...                 ...
# 193         Filed           2021-10-05       2-2021-051152
# 194         Filed           2021-10-05       2-2021-051151
# 195         Filed           2021-10-05       2-2021-051153
# 196         Filed           2021-10-05       2-2021-051150
# 197         Filed           2021-10-05       2-2021-051148
#
#                      Author                                       University
# 0        Lomboy, Orlando A.  Abra State Institute of Sciences and Technology
# 1        Venus, Victoria G.  Abra State Institute of Sciences and Technology
# 2         Gonzalo, Gemma P.  Abra State Institute of Sciences and Technology
# 3    Atmosfera, Rynheart P.  Abra State Institute of Sciences and Technology
# 4    Atmosfera, Rynheart P.  Abra State Institute of Sciences and Technology
# ..                      ...                                              ...
# 193   Puyongan, Bennylyn B.                         Benguet State University
# 194     Bugtong, Violeta B.                         Benguet State University
# 195     Bugtong, Violeta B.                         Benguet State University
# 196     Bugtong, Violeta B.                         Benguet State University
# 197     Bugtong, Violeta B.                         Benguet State University
#
# [198 rows x 10 columns]

# %%
def format_filter_patents(x):
    error_cols = []
    
    suc_list = ['Abra State Institute of Science and Technology', 
                'Agusan del Sur State College of Agriculture and Technology',
                'Benguet State University', 'Bulacan State University',
                'Davao del Norte State College', 'Mindoro State University',
                'Palawan State University', 'Tarlac State University', 
                'University of the Philippines Baguio', 
                'University of the Philippines Manila', 
                'Romblon State University'
               ]
    patent_type = ['Utility Model', 'Copyright', 'Industrial Design', 'Patent', 
                   'Trademark']
    
    patent_status = ['Registered', 'Filed', 'Pending', 'Inactive', 'Published']
    

    if not isinstance(x[3], str):
        title_error = 'Patent is not string.'
        error_cols.append(title_error)

    if ((x[4] != None) and (not isinstance(x[4], str)) and (x[4] not in patent_type)):
        type_error = 'Patent Type is not in list.'
        error_cols.append(type_error)
        
    if ((x[5] != None) and (not isinstance(x[5], str)) and (x[5] not in patent_status)):
        status_error = 'Patent Status is not in list.'
        error_cols.append(status_error)
        
    if ((x[6] != None) and (not isinstance(x[6], datetime.date))):
        date_error = 'Datetime Error'
        error_cols.append(date_error)
        
    if ((x[7] != None) and (not re.match('\d{1}-\d{4}-\d{6}', str(x[7])))):
        regno_error = 'Registration number format error.'
        error_cols.append(regno_error)

    if not isinstance(x[8], str):
        author_error = 'Author is not string.'
        error_cols.append(author_error)
    
    if ((x[9] != None) and (not isinstance(x[9], str)) and (x[9] not in suc_list)):
        suc_error = 'SUC is not in list.'
        error_cols.append(suc_error)

    if error_cols:
        return error_cols
    else:
        return 'No errors'

# %%
see = df_patents.apply(lambda row: format_filter_patents(row), axis=1)

# %%
see[0:30]
# Out:
# 0                               No errors
# 1                               No errors
# 2                               No errors
# 3                               No errors
# 4                               No errors
# 5                               No errors
# 6                               No errors
# 7                               No errors
# 8                               No errors
# 9                               No errors
# 10                              No errors
# 11                              No errors
# 12                              No errors
# 13                              No errors
# 14                              No errors
# 15                              No errors
# 16                              No errors
# 17                              No errors
# 18                              No errors
# 19                              No errors
# 20                              No errors
# 21                              No errors
# 22                              No errors
# 23                              No errors
# 24    [Registration number format error.]
# 25    [Registration number format error.]
# 26                              No errors
# 27    [Registration number format error.]
# 28    [Registration number format error.]
# 29    [Registration number format error.]
# dtype: object

# %%
df_patents['University'].unique()
# Out:
# array(['Abra State Institute of Sciences and Technology',
#        'Romblon State University', 'Davao del Norte State College',
#        'Mindoro State College of Agriculture and Technology',
#        'Bulacan State University', 'Benguet State University'],
#       dtype=object)

# %%
df_patents['Patent Type'].unique()
# Out:
# array(['Utility Model', 'Copyright', 'Industrial Design', 'Patent',
#        'Trademark'], dtype=object)

# %%
df_patents['Patent Status'].unique()
# Out:
# array(['Registered', 'Filed', 'Pending', 'Inactive', 'Published'],
#       dtype=object)

# %% [markdown]
# ## Utilization

# %%
df_utils = pd.read_excel('utilization.xlsx')

# %%
df_utils
# Out:
#    Team Member Input Date                                     Research Title  \
# 0        Chris 2022-04-05  Traditional Rice Varieties (Aromatic Rice): Gr...
# 1        Chris 2022-04-05  Agricultural Wastes As Potential Substrates Fo...
# 2        Chris 2022-04-05  The Response Of Tissue Cultured Banana (Musa S...
# 3        Chris 2022-04-05               Manobo Translator Mobile Application
# 4        Chris 2022-04-05  Development Of Isulat: A Mobile Instructional ...
# ..         ...        ...                                                ...
# 95      Marvee 2022-04-06  Low Cost Robotic Arm Trainer For K-12, Cit And...
# 96      Marvee 2022-04-06                                Oplan Kostal Aralan
# 97      Marvee 2022-04-06  Organizational Health And Its Effects On Teach...
# 98      Marvee 2022-04-06  The Effects And Stress In The Lives Of Field S...
# 99      Marvee 2022-04-06  Topographic Survey: Farm To Market Road Of Bul...
#
#                                       Product/Service  \
# 0              Technology In Growing Traditional Rice
# 1                     Growth Media From Organic Waste
# 2                               Fertilizer For Banana
# 3                                  Mobile Application
# 4                                  Mobile Application
# ..                                                ...
# 95                               The Prototype Itself
# 96                                      Kostal Aralan
# 97                           Educational Organization
# 98                     Seminar For Education Students
# 99  Topographic Survey: Farm To Market Road Of Bul...
#
#                   Simplified  \
# 0    Rice Growing Technology
# 1              Growth Medium
# 2                 Fertilizer
# 3         Mobile Application
# 4         Mobile Application
# ..                       ...
# 95       Robotic Arm Trainer
# 96              Kosal Aralan
# 97  Educational Organization
# 98                   Seminar
# 99                    Survey
#
#                                           Beneficiary  \
# 0                                  Francisca M. Badua
# 1   Loreta B. Alayon; Flora Anisco; Felicidad D. A...
# 2   Farmers Association of lower Agpan; Imelda Tec...
# 3                                     Indigent People
# 4                                            Teachers
# ..                                                ...
# 95              BulSU Students (BSIT, CIT, and Eng'g)
# 96  Taliptip Elementary School Students living in ...
# 97                                 Teachers; Students
# 98                                 Education Students
# 99                           Brgy. Bulihan, Main City
#
#                                            University   Campus  Year
# 0   Agusan del Sur State College of Agriculture an...     Main  2018
# 1   Agusan del Sur State College of Agriculture an...     Main  2018
# 2   Agusan del Sur State College of Agriculture an...     Main  2018
# 3   Agusan del Sur State College of Agriculture an...     Main  2019
# 4   Agusan del Sur State College of Agriculture an...     Main  2019
# ..                                                ...      ...   ...
# 95                           Bulacan State University   Bustos  2018
# 96                           Bulacan State University  Meneses  2017
# 97                           Bulacan State University     Main  2018
# 98                           Bulacan State University  Meneses  2021
# 99                           Bulacan State University     Main  2021
#
# [100 rows x 9 columns]

# %%
def format_filter_utils(x):
    error_cols = []
    
    sucs = {
        'Abra State Institute of Science and Technology':
            {'Abbreviation': 'ASIST', 
             'Campuses': ['Main', 'Bangued']},
        'Agusan del Sur State College of Agriculture and Technology':
            {'Abbreviation': 'ASSCAT', 
             'Campuses': ['Main', 'Trento']},
        'Benguet State University': 
            {'Abbreviation': 'BSU', 
             'Campuses': ['Main', 'Buguias', 'Bokod']},
        'Bulacan State University':
            {'Abbreviation': 'BulSU', 
             'Campuses': ['Main', 'Bustos', 'Meneses', 'Sarmiento', 'Hagonoy']},
        'Davao del Norte State College':
            {'Abbreviation': 'DNSC', 
             'Campuses': ['Main', 'Carmen', 'Sto. Tomas', 'IGACOS']},
        'Mindoro State University':
            {'Abbreviation': 'MinSU', 
             'Campuses': ['Main', 'Calapan', 'Bongabong']},
        'Palawan State University': 
            {'Abbreviation': 'PSU', 
             'Campuses': ['Main', 'Manalo']},
        'Tarlac State University':
            {'Abbreviation': 'TSU', 
             'Campuses': ['Main', 'San Isidro', 'Lucinda', 'Capas']},
        'University of the Philippines Baguio':
            {'Abbreviation': 'UP-Baguio',
             'Campuses': ['UPB']},
        'University of the Philippines Manila': 
            {'Abbreviation': 'UP-Manila',
             'Campuses': ['UPM']},
        'Romblon State University': 
            {'Abbreviation': 'RSU',
             'Campuses': ['Main', 'Romblon', 'Cajidiocan', 'San Fernando',
                          'San Andres', 'San Agustin', 'Calatrava', 'Santa Fe',
                          'Santa Maria']},
        }
    
    patent_type = ['Utility Model', 'Copyright', 'Industrial Design', 'Patent', 
                   'Trademark']
    
    patent_status = ['Registered', 'Filed', 'Pending', 'Inactive', 'Published']
    
    year_coverage = ['2017', '2018', '2019', '2020', '2021', '2022']
    

    if not isinstance(x[2], str):
        title_error = 'Title is not string.'
        error_cols.append(title_error)
        
    if not isinstance(x[3], str):
        ps_error = 'Product/Service is not string.'
        error_cols.append(ps_error)
        
    if not isinstance(x[4], str):
        simp_error = 'Simplified is not string.'
        error_cols.append(simp_error)

    if not isinstance(x[5], str):
        ben_error = 'Benficiary is not string.'
        error_cols.append(ben_error)

    if ((x[6] != None) and (not isinstance(x[6], str)) and (x[6] not in sucs.keys())):
        suc_error = 'SUC is not in list.'
        error_cols.append(suc_error)

    elif ((x[7] != None) and (not isinstance(x[7], str)) and (x[6] not in sucs[x[6]]['Campuses'])):
        suc_error = 'Campus is not in list.'
        error_cols.append(suc_error)
        
    if ((x[8] != None) and (not isinstance(x[8], int)) and (str(x[8]) not in year_coverage)):
        year_error = 'Year is not integer.'
        error_cols.append(year_error)

    if error_cols:
        return error_cols
    else:
        return 'No errors'

# %%
see = df_utils.apply(lambda row: format_filter_utils(row), axis=1)

# %%
see[60:]
# Out:
# 60    No errors
# 61    No errors
# 62    No errors
# 63    No errors
# 64    No errors
# 65    No errors
# 66    No errors
# 67    No errors
# 68    No errors
# 69    No errors
# 70    No errors
# 71    No errors
# 72    No errors
# 73    No errors
# 74    No errors
# 75    No errors
# 76    No errors
# 77    No errors
# 78    No errors
# 79    No errors
# 80    No errors
# 81    No errors
# 82    No errors
# 83    No errors
# 84    No errors
# 85    No errors
# 86    No errors
# 87    No errors
# 88    No errors
# 89    No errors
# 90    No errors
# 91    No errors
# 92    No errors
# 93    No errors
# 94    No errors
# 95    No errors
# 96    No errors
# 97    No errors
# 98    No errors
# 99    No errors
# dtype: object
